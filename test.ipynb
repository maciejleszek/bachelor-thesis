# %%
import pandas as pd

# %%
filename = 'data/20260105_8278074507_MiFitness_hlth_center_aggregated_fitness_data.csv'
df = pd.read_csv(filename)

# %%
print(list(df.columns))
# Out:
# ['Uid', 'Sid', 'Tag', 'Key', 'Time', 'Value', 'UpdateTime']

# %%
pd.get_option("display.max_colwidth")
# Out:
# 50

# %%
pd.set_option("display.max_colwidth", None)
df.Value[df.Key == 'sleep'][880]
# Out:
# '{"max_hr":61,"awake_count":1,"total_snore":0,"total_turn_over":0,"sleep_trace_duration":0,"sleep_manually_duration":0,"segment_details":[{"timezone":4,"sleep_awake_duration":4,"awake_count":1,"wake_up_time":1737271800,"max_hr":61,"duration":432,"min_hr":40,"sleep_deep_duration":152,"sleep_rem_duration":108,"avg_hr":50,"bedtime":1737245640,"sleep_light_duration":172}],"avg_spo2":0,"min_hr":40,"sleep_awake_duration":4,"avg_hr":50,"sleep_nap_duration":0,"sleep_score":83,"total_duration":432,"breath_quality":0,"day_sleep_evaluation":0,"sleep_rem_duration":108,"total_snore_disturb":0,"sleep_light_duration":172,"total_body_move":0,"total_long_duration":432,"sleep_deep_duration":152,"long_sleep_evaluation":26}'
